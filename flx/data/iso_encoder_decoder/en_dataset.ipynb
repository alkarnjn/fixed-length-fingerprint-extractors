# %%
from math import *

# convert minutiae template from txt format to iso19794-2-2005 format.


def to_iso19794(txtpath, isopath):
    width, height = 500, 610
    b_array = bytearray()
    with open(txtpath, "r") as textfile:
        lines = textfile.readlines()
    minutiae_num = len(lines)
    totalbytes = minutiae_num * 6 + 28 + 2

    b_array = bytearray(b"FMR\x00 20\x00")
    b_array += totalbytes.to_bytes(4, "big")
    b_array += bytearray(b"\x00\x00")
    b_array += width.to_bytes(2, "big")
    b_array += height.to_bytes(2, "big")
    b_array += bytearray(b"\x00\xc5\x00\xc5\x01\x00\x00\x00d")
    b_array += minutiae_num.to_bytes(1, "big")
    byte_list = [0, 0, 0, 0, 0, 0]
    for line in lines:
        line = line.split(" ")
        x, y, angle, min_type, quality = (
            int(float(line[0])),
            int(float(line[1])),
            int(float(line[2])),
            int(float(line[3])),
            int(float(line[4].strip())),
        )
        byte_list[1] = x % 256
        byte_list[0] = x // 256 + min_type * 64
        byte_list[2] = y // 256
        byte_list[3] = y % 256
        byte_list[4] = round((360 - angle) / 360 * 256) % 256
        byte_list[5] = quality
        b_array += bytearray(byte_list)

    zero = 0
    b_array += zero.to_bytes(2, "big")

    with open(isopath, "wb") as istfile:
        istfile.write(b_array)


def main():
    txtpath = "DB2_B optical/110_8.txt"
    isopath = "isoTemplate"
    to_iso19794(txtpath, isopath)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 53
#      49     to_iso19794(txtpath, isopath)
#      52 if __name__ == "__main__":
# ---> 53     main()
#
# Cell In[33], line 49, in main()
#      47 txtpath = "DB2_B optical/110_8.txt"
#      48 isopath = "isoTemplate"
# ---> 49 to_iso19794(txtpath, isopath)
#
# Cell In[33], line 37, in to_iso19794(txtpath, isopath)
#      35     byte_list[4] = round((360 - angle) / 360 * 256) % 256
#      36     byte_list[5] = quality
# ---> 37     b_array += bytearray(byte_list)
#      39 zero = 0
#      40 b_array += zero.to_bytes(2, "big")
#
# ValueError: byte must be in range(0, 256)

# %%
import glob
from math import *




def to_iso19794(txtpath, isopath):
    width, height = 500, 610
    b_array = bytearray()
    with open(txtpath, "r") as textfile:
        lines = textfile.readlines()
    minutiae_num = len(lines)
    totalbytes = minutiae_num * 6 + 28 + 2

    b_array = bytearray(b"FMR\x00 20\x00")
    b_array += totalbytes.to_bytes(4, "big")
    b_array += bytearray(b"\x00\x00")
    b_array += width.to_bytes(2, "big")
    b_array += height.to_bytes(2, "big")
    b_array += bytearray(b"\x00\xc5\x00\xc5\x01\x00\x00\x00d")
    b_array += minutiae_num.to_bytes(1, "big")
    byte_list = [0, 0, 0, 0, 0, 0]
    for line in lines:
        line = line.split(" ")
        x, y, angle, min_type, quality = (
            int(float(line[0])),
            int(float(line[1])),
            int(float(line[2])),
            int(float(line[3])),
            int(float(line[4].strip())),
        )
        byte_list[1] = x % 256
        byte_list[0] = x // 256 + min_type * 64
        byte_list[2] = y // 256
        byte_list[3] = y % 256
        byte_list[4] = round((360 - angle) / 360 * 256)
        byte_list[5] = quality
        b_array += bytearray(byte_list)

    zero = 0
    b_array += zero.to_bytes(2, "big")

    with open(isopath, "wb") as istfile:
        istfile.write(b_array)




def main():
    # Get a list of all the text file paths in the dataset
    txt_file_paths = glob.glob("DB2_B optical/*.txt")

    # Iterate through the list of text file paths
    for txt_file_path in txt_file_paths:
        # Generate the output ISO/IEC 19794-2:2005 file path
        iso_file_path = txt_file_path.replace(".txt", ".ist")

        # Convert the text file to ISO/IEC 19794-2:2005 format
        to_iso19794(txt_file_path, iso_file_path)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 62
#      59         to_iso19794(txt_file_path, iso_file_path)
#      61 if __name__ == "__main__":
# ---> 62     main()
#
# Cell In[25], line 59, in main()
#      56 iso_file_path = txt_file_path.replace(".txt", ".ist")
#      58 # Convert the text file to ISO/IEC 19794-2:2005 format
# ---> 59 to_iso19794(txt_file_path, iso_file_path)
#
# Cell In[25], line 38, in to_iso19794(txtpath, isopath)
#      36     byte_list[4] = round((360 - angle) / 360 * 256)
#      37     byte_list[5] = quality
# ---> 38     b_array += bytearray(byte_list)
#      40 zero = 0
#      41 b_array += zero.to_bytes(2, "big")
#
# ValueError: byte must be in range(0, 256)
